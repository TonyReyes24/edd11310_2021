# %% [markdown]
# <a href="https://colab.research.google.com/github/TonyReyes24/edd11310_2021/blob/master/26_enero_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class NodoArbol: #Binario
    def __init__(self,value,left=None,right=None):
        self.data=value
        self.left=left
        self.right=right

class BinarySearchTree:
    def __init__(self):
        self.__root=None

    def insert(self, value):
        #Regla 1
        if self.__root == None:
            self.__root = NodoArbol(value,None,None)
        #Regla 2
        else:
            self.__insert__(self.__root , value)
    
    def __insert__(self , nodo , value):
        if nodo.data == value:
            print("El dato ya existe, no se ingresa nada")
        elif value < nodo.data:
            #Regla 1
            if nodo.left == None:
                nodo.left = NodoArbol(value)
            #Regla 2
            else:
                self.__insert__(nodo.left , value)
        else:
            if nodo.right == None:
                nodo.right = NodoArbol(value)
            else:
                self.__insert__(nodo.right , value)

    def __recorrido_in( self, nodo ):
        if nodo:
            self.__recorrido_in( nodo.left )
            print( nodo.data, end=", " )
            self.__recorrido_in( nodo.right  )


    def __recorrido_pos( self, nodo ):
        if nodo:
            self.__recorrido_pos(nodo.left)
            self.__recorrido_pos(nodo.right)
            print(nodo.data, end=", ")
    

    def __recorrido_pre( self, nodo ):
        if nodo:
            print(nodo.data, end=", ")
            self.__recorrido_pre(nodo.left)
            self.__recorrido_pre(nodo.right)

    def transversal(self , format="inorden"):
        if format == "inorden":
            print("Recorrido en Inorden")
            self.__recorrido_in(self.__root)
        elif format == "preorden":
            print("Recorrido en Preorden")
            self.__recorrido_pre(self.__root)
        elif format == "posorden":
            print("Recorrido en Posorden")
            self.__recorrido_pos(self.__root)
        else:
            print("Error, ese formato no existe")
        print()
    
    def search(self , value):
        if self.__root == None:
            return None
        else:
            return self.__search(self.__root , value)

    def __search(self , nodo , value):
        if nodo == None: #Vacio ?? Caso base de recursividad
            #print("Caso base")
            return None
        elif nodo.data == value: #Caso base de recursividad
            #print("Encontrado")
            return nodo
        elif value < nodo.data:
            #print("Buscar a la izquierda")
            return self.__search(nodo.left , value) 
        else:
            #print("Buscar a la derecha")
            return self.__search(nodo.right , value) 

    def remove(self , value):
        if self.__root == None:
            print("Nada que eliminar")
        else:
            self.__remove(None, None, self.__root, value)

    def __remove(self, padre_hi, padre_hd , actual , value):
        if actual == None:
            print("Caso base")
            return None
        elif actual.data == value: #Caso base
            print("Encontrado", actual.data)
            #Caso 1 (hoja)
            if actual.left == None and actual.right == None:
                if padre_hi != None:
                    padre_hi.left = None
                else:
                    padre_hd.right = None
            #Caso 2 (Tiene un hijo)
            if (actual.left != None and actual.right == None) or\
             (actual.left == None and actual.right != None):
                print(actual.data, "Es un nodo con un hijo")
                if actual.left != None:
                    actual.data = actual.left.data
                    actual.left = None
                else:
                    actual.data = actual.right.data
                    actual.right = None
            #Caso 3 (Tiene dos hijos)


            #return actual
        elif value < actual.data:
            #print("Buscar a ala Izquierda")
            self.__remove(actual, None, actual.left, value)
        else:
            #print("Buscar a ala Derecha")
            self.__remove(None, actual, actual.right, value)


#pruebas_abb.py
#from arboles_binarios import BinarySearchTree
abb = BinarySearchTree()
abb.insert(50)
abb.insert(30)
abb.insert(60)
abb.insert(15)
abb.insert(23)
abb.insert(110)
abb.insert(90)
abb.insert(120)
abb.insert(100)
abb.insert(55)
abb.insert(58)
abb.insert(115)

abb.transversal()
print("--------------------")
abb.remove(90)
abb.transversal()
# Out:
# Recorrido en Inorden
# 15, 23, 30, 50, 55, 58, 60, 90, 100, 110, 115, 120,
# --------------------
# Encontrado 90
# 90 Es un nodo con un hijo
# Recorrido en Inorden
# 15, 23, 30, 50, 55, 58, 60, 100, 110, 115, 120,
